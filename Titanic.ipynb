# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/KANAWADE AKSHAY/Downloads/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 834          835         0       3
# 648          649         0       3
# 207          208         1       3
# 640          641         0       3
# 805          806         0       3
# 129          130         0       3
# 184          185         1       3
# 739          740         0       3
# 858          859         1       3
# 220          221         1       3
# 486          487         1       1
# 638          639         0       3
# 487          488         0       1
# 355          356         0       3
# 316          317         1       2
# 151          152         1       1
# 208          209         1       3
# 851          852         0       3
# 579          580         1       3
# 314          315         0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 834                           Allum, Mr. Owen George    male  18.0      0
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.ndim
# Out:
# 2

# %%
df[df['Embarked'] == 'C'].count
# Out:
# <bound method DataFrame.count of      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.columns  #df.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
# no of passenger in each class
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby(['Name','Pclass','Ticket']).groups
# Out:
# {('Abbing, Mr. Anthony', 3, 'C.A. 5547'): Int64Index([845], dtype='int64'),
#  ('Abbott, Mr. Rossmore Edward',
#   3,
#   'C.A. 2673'): Int64Index([746], dtype='int64'),
#  ('Abbott, Mrs. Stanton (Rosa Hunt)',
#   3,
#   'C.A. 2673'): Int64Index([279], dtype='int64'),
#  ('Abelson, Mr. Samuel', 2, 'P/PP 3381'): Int64Index([308], dtype='int64'),
#  ('Abelson, Mrs. Samuel (Hannah Wizosky)',
#   2,
#   'P/PP 3381'): Int64Index([874], dtype='int64'),
#  ('Adahl, Mr. Mauritz Nils Martin',
#   3,
#   'C 7076'): Int64Index([365], dtype='int64'),
#  ('Adams, Mr. John', 3, '341826'): Int64Index([401], dtype='int64'),
#  ('Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#   3,
#   '7546'): Int64Index([40], dtype='int64'),
#  ('Aks, Mrs. Sam (Leah Rosen)', 3, '392091'): Int64Index([855], dtype='int64'),
#  ('Albimona, Mr. Nassef Cassem', 3, '2699'): Int64Index([207], dtype='int64'),
#  ('Alexander, Mr. William', 3, '3474'): Int64Index([810], dtype='int64'),
#  ('Alhomaki, Mr. Ilmari Rudolf',
# ...

# %%
#max ticket
df['Ticket'].max()
# Out:
# 'WE/P 5735'

# %%
# min ticket
df['Pclass'].min()
# Out:
# 1

# %%
df[df['Pclass'] == df['Pclass'].min()][['Name','Cabin','Ticket']]
# Out:
#                                                   Name        Cabin    Ticket
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          C85  PC 17599
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         C123    113803
# 6                              McCarthy, Mr. Timothy J          E46     17463
# 11                            Bonnell, Miss. Elizabeth         C103    113783
# 23                        Sloper, Mr. William Thompson           A6    113788
# ..                                                 ...          ...       ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          D35     11751
# 872                           Carlsson, Mr. Frans Olof  B51 B53 B55       695
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          C50     11767
# 887                       Graham, Miss. Margaret Edith          B42    112053
# 889                              Behr, Mr. Karl Howell         C148    111369
#
# [216 rows x 3 columns]

# %%
df[df['Ticket']=='LINE']
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 179          180         0       3              Leonard, Mr. Lionel  male
# 271          272         1       3     Tornquist, Mr. William Henry  male
# 302          303         0       3  Johnson, Mr. William Cahoone Jr  male
# 597          598         0       3              Johnson, Mr. Alfred  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 179  36.0      0      0   LINE   0.0   NaN        S
# 271  25.0      0      0   LINE   0.0   NaN        S
# 302  19.0      0      0   LINE   0.0   NaN        S
# 597  49.0      0      0   LINE   0.0   NaN        S

# %%
df[df['Fare']==df['Fare'].min()][['PassengerId','Name','Pclass','Fare']]
# Out:
#      PassengerId                              Name  Pclass  Fare
# 179          180               Leonard, Mr. Lionel       3   0.0
# 263          264             Harrison, Mr. William       1   0.0
# 271          272      Tornquist, Mr. William Henry       3   0.0
# 277          278       Parkes, Mr. Francis "Frank"       2   0.0
# 302          303   Johnson, Mr. William Cahoone Jr       3   0.0
# 413          414    Cunningham, Mr. Alfred Fleming       2   0.0
# 466          467             Campbell, Mr. William       2   0.0
# 481          482  Frost, Mr. Anthony Wood "Archie"       2   0.0
# 597          598               Johnson, Mr. Alfred       3   0.0
# 633          634     Parr, Mr. William Henry Marsh       1   0.0
# 674          675        Watson, Mr. Ennis Hastings       2   0.0
# 732          733              Knight, Mr. Robert J       2   0.0
# 806          807            Andrews, Mr. Thomas Jr       1   0.0
# ...

# %%
df[df['Fare'].apply(lambda x: (x) <= 5)]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 378          379         0       3               Betros, Mr. Tannous  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# ...

# %%
group = df.groupby('Pclass')

# %%
group['PassengerId'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
group.agg(np.size)
# Out:
#         PassengerId  Survived  Name  Sex    Age  SibSp  Parch  Ticket   Fare  \
# Pclass
# 1               216       216   216  216  216.0    216    216     216  216.0
# 2               184       184   184  184  184.0    184    184     184  184.0
# 3               491       491   491  491  491.0    491    491     491  491.0
#
#         Cabin  Embarked
# Pclass
# 1         216       216
# 2         184       184
# 3         491       491
