# %% [markdown]
# # covid 19 dataset

# %%
# Import pandas library
import pandas as pd
import numpy as np

# %%
# read dataset
df = pd.read_csv('/Users/KANAWADE AKSHAY/Downloads/corona_India_latest_04-23-2020_10_58.csv')

# %%
#dataset
df
# Out:
#     Unnamed: 0           Name of State / UT  Total Confirmed cases  \
# 0            0  Andaman and Nicobar Islands                     18
# 1            1               Andhra Pradesh                    813
# 2            2            Arunachal Pradesh                      1
# 3            3                        Assam                     35
# 4            4                        Bihar                    143
# 5            5                   Chandigarh                     27
# 6            6                 Chhattisgarh                     36
# 7            7                        Delhi                   2248
# 8            8                          Goa                      7
# 9            9                      Gujarat                   2407
# 10          10                      Haryana                    262
# 11          11             Himachal Pradesh                     40
# 12          12            Jammu and Kashmir                    407
# ...

# %%
#print first five data
df.head(5)
# Out:
#    Unnamed: 0           Name of State / UT  Total Confirmed cases  \
# 0           0  Andaman and Nicobar Islands                     18
# 1           1               Andhra Pradesh                    813
# 2           2            Arunachal Pradesh                      1
# 3           3                        Assam                     35
# 4           4                        Bihar                    143
#
#    Cured/Discharged/Migrated  Death
# 0                         11      0
# 1                        120     24
# 2                          1      0
# 3                         19      1
# 4                         46      2

# %%
#print last 5  data
df.tail(5)
# Out:
#     Unnamed: 0 Name of State / UT  Total Confirmed cases  \
# 27          27          Telengana                    945
# 28          28            Tripura                      2
# 29          29        Uttarakhand                     46
# 30          30      Uttar Pradesh                   1449
# 31          31        West Bengal                    456
#
#     Cured/Discharged/Migrated  Death
# 27                        194     23
# 28                          1      0
# 29                         23      0
# 30                        173     21
# 31                         79     15

# %%
#print data sample
df.sample(5)
# Out:
#     Unnamed: 0 Name of State / UT  Total Confirmed cases  \
# 16          16             Ladakh                     18
# 28          28            Tripura                      2
# 19          19            Manipur                      2
# 31          31        West Bengal                    456
# 29          29        Uttarakhand                     46
#
#     Cured/Discharged/Migrated  Death
# 16                         14      0
# 28                          1      0
# 19                          2      0
# 31                         79     15
# 29                         23      0

# %%
#shape of dataframe
df.shape
# Out:
# (32, 5)

# %%
# dim of dataframe
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=32, step=1),
#  Index(['Unnamed: 0', 'Name of State / UT', 'Total Confirmed cases',
#         'Cured/Discharged/Migrated', 'Death'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# Name of State / UT           object
# Total Confirmed cases         int64
# Cured/Discharged/Migrated     int64
# Death                         int64
# dtype: object

# %%
df.size
# Out:
# 160

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 32 non-null     int64
#  1   Name of State / UT         32 non-null     object
#  2   Total Confirmed cases      32 non-null     int64
#  3   Cured/Discharged/Migrated  32 non-null     int64
#  4   Death                      32 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.2+ KB

# %%
df.columns=['id','state','confirmed','cured','death']
pd.DataFrame(df,columns=['id','state','confirmed','cured','death'])
# Out:
#     id                        state  confirmed  cured  death
# 0    0  Andaman and Nicobar Islands         18     11      0
# 1    1               Andhra Pradesh        813    120     24
# 2    2            Arunachal Pradesh          1      1      0
# 3    3                        Assam         35     19      1
# 4    4                        Bihar        143     46      2
# 5    5                   Chandigarh         27     14      0
# 6    6                 Chhattisgarh         36     26      0
# 7    7                        Delhi       2248    724     48
# 8    8                          Goa          7      7      0
# 9    9                      Gujarat       2407    179    103
# 10  10                      Haryana        262    140      3
# 11  11             Himachal Pradesh         40     18      1
# 12  12            Jammu and Kashmir        407     92      5
# 13  13                    Jharkhand         49      8      3
# ...

# %%
df.columns     #df.keys()
# Out:
# Index(['id', 'state', 'confirmed', 'cured', 'death'], dtype='object')

# %%
#change columns name
df.columns=['id','state','confirmed','cured','death']

# %%
df.describe()
# Out:
#               id   confirmed       cured       death
# count  32.000000    32.00000   32.000000   32.000000
# mean   15.500000   668.53125  133.062500   21.281250
# std     9.380832  1161.49481  210.302231   50.993506
# min     0.000000     1.00000    0.000000    0.000000
# 25%     7.750000    18.00000   10.250000    0.000000
# 50%    15.500000   113.00000   39.000000    2.500000
# 75%    23.250000   846.00000  154.250000   18.750000
# max    31.000000  5652.00000  789.000000  269.000000

# %%
df.sum()
# Out:
# id                                                         496
# state        Andaman and Nicobar IslandsAndhra PradeshAruna...
# confirmed                                                21393
# cured                                                     4258
# death                                                      681
# dtype: object

# %%
df['confirmed'].sum()
# Out:
# 21393

# %%
df['cured'].sum()
# Out:
# 4258

# %%
df['death'].sum()
# Out:
# 681

# %%
df[df['death']==df['death'].max()]
# Out:
#     id        state  confirmed  cured  death
# 18  18  Maharashtra       5652    789    269

# %%
df[df['cured']==df['cured'].max()]
# Out:
#     id        state  confirmed  cured  death
# 18  18  Maharashtra       5652    789    269

# %%
df[df['confirmed']==df['confirmed'].max()]
# Out:
#     id        state  confirmed  cured  death
# 18  18  Maharashtra       5652    789    269

# %%
df.sort_values(by='confirmed')
# Out:
#     id                        state  confirmed  cured  death
# 21  21                      Mizoram          1      0      0
# 2    2            Arunachal Pradesh          1      1      0
# 19  19                      Manipur          2      2      0
# 28  28                      Tripura          2      1      0
# 23  23                   Puducherry          7      3      0
# 8    8                          Goa          7      7      0
# 20  20                    Meghalaya         12      0      1
# 16  16                       Ladakh         18     14      0
# 0    0  Andaman and Nicobar Islands         18     11      0
# 5    5                   Chandigarh         27     14      0
# 3    3                        Assam         35     19      1
# 6    6                 Chhattisgarh         36     26      0
# 11  11             Himachal Pradesh         40     18      1
# 29  29                  Uttarakhand         46     23      0
# ...

# %%
list(df[df['death']==df['death'].min()]['state'])
# Out:
# ['Andaman and Nicobar Islands',
#  'Arunachal Pradesh',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Goa',
#  'Ladakh',
#  'Manipur',
#  'Mizoram',
#  'Puducherry',
#  'Tripura',
#  'Uttarakhand']

# %%
df[df['cured']==df['cured'].min()]
# Out:
#     id      state  confirmed  cured  death
# 20  20  Meghalaya         12      0      1
# 21  21    Mizoram          1      0      0

# %%
list(df[df['confirmed']==df['confirmed'].min()]['state'])
# Out:
# ['Arunachal Pradesh', 'Mizoram']

# %%
df[df['state'] == 'Maharashtra']
# Out:
#     id        state  confirmed  cured  death
# 18  18  Maharashtra       5652    789    269
